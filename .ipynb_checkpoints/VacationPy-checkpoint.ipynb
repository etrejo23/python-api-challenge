# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
weather_data=pd.read_csv('Weather Data.csv')
weather_data.head(10)
# Out:
#    Unnamed: 0             City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           0     Port Lincoln -34.73  135.87     58.60        54         100
# 1           1  Puerto Colombia  10.99  -74.95     80.60        83          20
# 2           2       Shitanjing  39.23  106.34     69.62        31           7
# 3           3       Zhezkazgan  47.80   67.71     67.68        35         100
# 4           4        Ambovombe -25.17   46.08     65.59        94           8
# 5           5           Dikson  73.51   80.55     44.96        90          30
# 6           6     Puerto Ayora  -0.74  -90.35     64.92        83          97
# 7           7           Gornyy  55.12   83.91     59.43        77         100
# 8           8            Orsha  54.52   30.41     55.00        91          99
# 9           9          Tighina  46.83   29.47     60.80        72           0
#
#    Wind Speed Country        Date
# 0       18.19      AU  1598923785
# 1        5.82      CO  1598923687
# 2        9.04      CN  1598923786
# 3       10.33      KZ  1598923786
# 4        5.23      MG  1598923786
# 5        6.71      RU  1598923786
# 6       10.22      EC  1598923659
# 7       13.69      RU  1598923787
# 8       12.01      BY  1598923787
# 9        2.24      MD  1598923787

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
locations = weather_data[["Lat", "Lng"]]
humidity = weather_data["Humidity"].astype(float)
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
ideal_weather=weather_data.loc[(weather_data['Max Temp']<=80)&(weather_data['Max Temp']>=70)&(weather_data['Wind Speed']<=10)&(weather_data['Cloudiness']<=20)]
ideal_weather=ideal_weather.dropna()
ideal_weather
# Out:
#      Unnamed: 0                 City    Lat     Lng  Max Temp  Humidity  \
# 23           23   Nizhniy Baskunchak  48.22   46.83     72.59        30
# 45           45                Airai  -8.93  125.41     73.13        58
# 61           61             Bengkulu  -3.80  102.27     78.13        86
# 68           68               Graham  47.05 -122.29     72.00        49
# 97           97               Cumpas  29.98 -109.78     77.47        75
# 127         127             Javānrūd  34.80   46.52     73.40        47
# 130         130               Yulara -25.24  130.99     73.40        25
# 177         177               Mehrān  33.12   46.16     75.20        27
# 189         189            Crestview  30.76  -86.57     79.00        83
# 263         263           Tlapacoyan  19.97  -97.22     79.21        81
# 273         273          Miandrivazo -19.52   45.47     70.39        67
# 296         296                  Hūn  29.13   15.95     73.71        40
# 297         297              Yeppoon -23.13  150.73     75.20        47
# 298         298                 Jaru -10.44  -62.47     79.41        52
# 305         305               Manono  -7.30   27.42     72.59        77
# 312         312              Biloela -24.42  150.50     78.71        29
# 316         316                Kumul  42.80   93.45     73.94        20
# 332         332  São Raimundo Nonato  -9.02  -42.70     75.24        51
# 363         363              Cayenne   4.93  -52.33     78.80        88
# 368         368           Los Alamos  35.89 -106.31     70.00        35
# 370         370               Grants  35.15 -107.85     73.40        31
# 372         372             Syracuse  37.09   15.28     78.80        83
# 374         374                Iporá -16.44  -51.12     73.65        26
# 383         383               Beyneu  45.32   55.20     73.81        21
# 450         450              Canindé  -4.36  -39.31     70.79        87
# 454         454               Bukama  -9.20   25.85     70.34        74
# 460         460        Sedro-Woolley  48.50 -122.24     71.60        49
# 464         464            Dom Pedro  -4.48  -44.45     77.22        37
# 472         472             Neftçala  39.37   49.25     73.87        71
# 485         485          Derzhavīnsk  51.10   66.32     70.54        39
# 499         499         Guayaramerín -10.84  -65.36     76.01        74
# 522         522     Praia da Vitória  38.73  -27.07     71.60        73
# 538         538             La Palma  33.85 -118.05     77.00        53
#
#      Cloudiness  Wind Speed Country        Date
# 23            0        6.91      RU  1598923790
# 45            0        7.38      TL  1598923794
# 61            3        5.17      ID  1598923798
# 68            1        4.70      US  1598923799
# 97            5        4.23      MX  1598923810
# 127           3        6.93      IR  1598923816
# 130           0        4.70      AU  1598923817
# 177          20        6.93      IR  1598923827
# 189           1        4.45      US  1598923829
# 263           4        3.31      MX  1598923845
# 273           0        1.28      MG  1598923847
# 296           0        5.91      LY  1598923852
# 297          20        5.82      AU  1598923852
# 298           0        3.29      BR  1598923853
# 305           5        0.92      CD  1598923854
# 312           0        3.96      AU  1598923855
# 316           0        7.94      CN  1598923650
# 332           0        6.58      BR  1598923859
# 363           0        3.36      GF  1598923663
# 368           1        4.70      US  1598923866
# 370           1        8.05      US  1598923867
# 372           0        4.70      IT  1598923867
# 374           0        4.25      BR  1598923868
# 383           0        7.11      KZ  1598923870
# 450           0        1.39      BR  1598923883
# 454           3        0.76      CD  1598923884
# 460           1        5.82      US  1598923885
# 464           0        3.33      BR  1598923809
# 472           0        9.17      AZ  1598923888
# 485           0        0.60      KZ  1598923890
# 499           4        1.79      BO  1598923894
# 522          20        9.01      PT  1598923898
# 538           1        9.17      US  1598923875

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df=ideal_weather
hotel_df["Hotel Name"]=""
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key,
}
# use iterrows to iterate through pandas dataframe
for index, row in hotel_df.iterrows():
    params["location"]= f"{row['Lat']},{row['Lng']}"
    response= requests.get(base_url, params=params).json()
    try:
        hotel_df.loc[index,"Hotel Name"]=response['results'][0]['name']
        print("Hotel Found")
    except Exception as e: 
        print("City not found. Skipping...")
        print(e) #it will print the exception itself
        pass
# Out:
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found
# City not found. Skipping...
# list index out of range
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found
# Hotel Found

# %%
hotel_df
# Out:
#      Unnamed: 0                 City    Lat     Lng  Max Temp  Humidity  \
# 23           23   Nizhniy Baskunchak  48.22   46.83     72.59        30
# 45           45                Airai  -8.93  125.41     73.13        58
# 61           61             Bengkulu  -3.80  102.27     78.13        86
# 68           68               Graham  47.05 -122.29     72.00        49
# 97           97               Cumpas  29.98 -109.78     77.47        75
# 127         127             Javānrūd  34.80   46.52     73.40        47
# 130         130               Yulara -25.24  130.99     73.40        25
# 177         177               Mehrān  33.12   46.16     75.20        27
# 189         189            Crestview  30.76  -86.57     79.00        83
# 263         263           Tlapacoyan  19.97  -97.22     79.21        81
# 273         273          Miandrivazo -19.52   45.47     70.39        67
# 296         296                  Hūn  29.13   15.95     73.71        40
# 297         297              Yeppoon -23.13  150.73     75.20        47
# 298         298                 Jaru -10.44  -62.47     79.41        52
# 305         305               Manono  -7.30   27.42     72.59        77
# 312         312              Biloela -24.42  150.50     78.71        29
# 316         316                Kumul  42.80   93.45     73.94        20
# 332         332  São Raimundo Nonato  -9.02  -42.70     75.24        51
# 363         363              Cayenne   4.93  -52.33     78.80        88
# 368         368           Los Alamos  35.89 -106.31     70.00        35
# 370         370               Grants  35.15 -107.85     73.40        31
# 372         372             Syracuse  37.09   15.28     78.80        83
# 374         374                Iporá -16.44  -51.12     73.65        26
# 383         383               Beyneu  45.32   55.20     73.81        21
# 450         450              Canindé  -4.36  -39.31     70.79        87
# 454         454               Bukama  -9.20   25.85     70.34        74
# 460         460        Sedro-Woolley  48.50 -122.24     71.60        49
# 464         464            Dom Pedro  -4.48  -44.45     77.22        37
# 472         472             Neftçala  39.37   49.25     73.87        71
# 485         485          Derzhavīnsk  51.10   66.32     70.54        39
# 499         499         Guayaramerín -10.84  -65.36     76.01        74
# 522         522     Praia da Vitória  38.73  -27.07     71.60        73
# 538         538             La Palma  33.85 -118.05     77.00        53
#
#      Cloudiness  Wind Speed Country        Date  \
# 23            0        6.91      RU  1598923790
# 45            0        7.38      TL  1598923794
# 61            3        5.17      ID  1598923798
# 68            1        4.70      US  1598923799
# 97            5        4.23      MX  1598923810
# 127           3        6.93      IR  1598923816
# 130           0        4.70      AU  1598923817
# 177          20        6.93      IR  1598923827
# 189           1        4.45      US  1598923829
# 263           4        3.31      MX  1598923845
# 273           0        1.28      MG  1598923847
# 296           0        5.91      LY  1598923852
# 297          20        5.82      AU  1598923852
# 298           0        3.29      BR  1598923853
# 305           5        0.92      CD  1598923854
# 312           0        3.96      AU  1598923855
# 316           0        7.94      CN  1598923650
# 332           0        6.58      BR  1598923859
# 363           0        3.36      GF  1598923663
# 368           1        4.70      US  1598923866
# 370           1        8.05      US  1598923867
# 372           0        4.70      IT  1598923867
# 374           0        4.25      BR  1598923868
# 383           0        7.11      KZ  1598923870
# 450           0        1.39      BR  1598923883
# 454           3        0.76      CD  1598923884
# 460           1        5.82      US  1598923885
# 464           0        3.33      BR  1598923809
# 472           0        9.17      AZ  1598923888
# 485           0        0.60      KZ  1598923890
# 499           4        1.79      BO  1598923894
# 522          20        9.01      PT  1598923898
# 538           1        9.17      US  1598923875
#
#                                             Hotel Name
# 23                                         Arman hotel
# 45                                      Juvinal Martin
# 61                                Grage Hotel Bengkulu
# 68                                Moxie Meadows Hostel
# 97                                      Hotel La Palma
# 127                                            هتل چیا
# 130           Desert Gardens Hotel - Ayers Rock Resort
# 177                                   بوتیک زنانه بهار
# 189  Holiday Inn Express & Suites Crestview South I-10
# 263                                    Hotel San Diego
# 273                      Hôtel Arc En Ciel Miandrivazo
# 296                                      Alrwasi Hotel
# 297                                   Villa Mar Colina
# 298                                       Hotel Paraná
# 305                                    Hotel hewa bora
# 312                                     Silo Motor Inn
# 316                                   Laoyutang Resort
# 332                                         Real Hotel
# 363                                    Hôtel Le Dronmi
# 368  Holiday Inn Express & Suites Los Alamos Entrad...
# 370                                 Motel 6 Grants, NM
# 372                                        Hotel Posta
# 374                                        Oásis Motel
# 383                                                NUR
# 450                               Hotel Casa Grande II
# 454
# 460                       Natural Resources Department
# 464                               Pousada Santa Amália
# 472                                          Göl hotel
# 485                                      Ooo.khim Baza
# 499                                        Hostal FÜNF
# 522                                     Hotel Branco I
# 538       La Quinta Inn & Suites by Wyndham Buena Park

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations)
fig.add_layer(markers)
fig

# Display figure
# Out:
# Figure(layout=FigureLayout(height='420px'))
